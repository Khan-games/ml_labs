# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# CONSTANTS
C_TOLERANCE = 1e-5 # stop condition
C_ALPHA = 0.02 # learning rate
C_MAX_EPOCH = 2000 # max epoch count

# %%
# load data from csv to numpy arrays
data_train = np.genfromtxt('lab_1_train.csv', delimiter = ',')
data_test = np.genfromtxt('lab_1_test.csv', delimiter = ',')

# convert data to suitable format
#  separate train data
train_x = data_train[1:,1] 
train_y = data_train[1:,2]

#  separate test data
test_x = data_test[1:,1] 
test_y = data_test[1:,2]

# data for each parameter is now stored in a separate array

# show data using pyplot
plt.plot(train_x, train_y, 'o', label="train")
plt.plot(test_x, test_y, 'o', label="test")   
plt.legend()
plt.show()

# %%
def plot_regression_line(bias, weight, data_x=None, data_y=None, back_data=True, show=True):
    x = np.linspace(0, 1, 2) # x goes from 0 to 1, using 2 points
    plt.plot(x, bias + weight * x, label="y = {0} + {1}x".format(round(bias, 3), round(weight, 3)))
    if back_data:
        if data_x.shape[0] == 0 or data_y.shape[0] == 0:
            print("No data to plot.")
        else:
            plt.plot(train_x, train_y, 'o', label="train")
            plt.plot(test_x, test_y, 'o', label="test") 
    plt.legend()
    if show:
        plt.show()

def cost_function(data_x, data_y, bias, weight):
    return 0.5 * np.sum((data_y - (bias + data_x * weight)) ** 2) / data_x.shape[0]

def calc_y_array(data_x, bias, weight):
    return bias + data_x * weight

def weight_grad(y, y_true, x):
    return np.sum((y - y_true) * x)

def bias_grad(y, y_true, x):
    return np.sum(y - y_true)

def print_epoch(index, cf, bias, weight):
    print("Epoch {0}:\tBias = {1},\tWeight = {2},\tCost function = {3}".format(index, round(bias, 8), 
                                                                            round(weight, 8), round(cf, 8)))

def train(data_x, data_y, bias, weight):
    curr_epoch = 0 # counts epoch
    # save some value for the next epoch
    prev_bias = bias
    prev_weight = weight
    prev_cf = cost_function(data_x, data_y, bias, weight) 
    
    print_epoch(curr_epoch, prev_cf, bias, weight)
    print()
    while (curr_epoch < C_MAX_EPOCH):
        curr_epoch += 1
        
        # predict y
        pred_y = calc_y_array(data_x, bias, weight)
        
        # calc new bias and weight
        bias = bias - C_ALPHA * bias_grad(pred_y, data_y, data_x)
        weight = weight - C_ALPHA * weight_grad(pred_y, data_y, data_x)
        
        # calc new cost function
        cf = cost_function(data_x, data_y, bias, weight)
        print_epoch(curr_epoch, cf, bias, weight)
        print("DIFF:\t\tBias = {0},\tWeight = {1},\tCost function = {2}\n".format(round(bias - prev_bias, 8), 
                                                                             round(weight - prev_weight, 8),  
                                                                             round(cf - prev_cf, 8))) 
        
        # check tolerance
        if (abs(bias - prev_bias) < C_TOLERANCE) and (abs(weight - prev_weight) < C_TOLERANCE):
            break
            
        # update saved values
        prev_cf = cf
        prev_weight = weight
        prev_bias = bias
    else:
        print("\nTraining is over due to exceeding the number of epochs.\n")
    
    return bias, weight

def train_init(data_x, data_y, test_x, test_y):
    # choose random bias and weight
    bias = np.random.rand()
    weight = np.random.rand()
    print("Start bias =\t", bias,"\n", "Start weight =\t", weight, sep="")
    plot_regression_line(bias, weight, back_data=False)
    
    # run training session
    bias, weight = train(data_x, data_y, bias, weight)
    
    # results
    print("\n\n\tTRAINING RESULTS")
    print("Bias = {0}\nWeight = {1}\nCost function (train data) = \t{2}\nCost function (test data) = \t{3}".format(bias, 
                weight, cost_function(data_x, data_y, bias, weight), cost_function(test_x, test_y, bias, weight)))
    plot_regression_line(bias, weight, data_x, data_y, back_data=True, show=True)

# %%
train_init(train_x, train_y, test_x, test_y)
# Out:
# Start bias =	0.9410072448131951
# Start weight =	0.014891204187242879
# Epoch 0:	Bias = 0.94100724,	Weight = 0.0148912,	Cost function = 192.25626335
#
# Epoch 1:	Bias = 24.46594965,	Weight = 7.09696443,	Cost function = 18.62463648
# DIFF:		Bias = 23.5249424,	Weight = 7.08207322,	Cost function = -173.63162687
#
# Epoch 2:	Bias = 17.22858347,	Weight = 4.75243216,	Cost function = 1.9684532
# DIFF:		Bias = -7.23736618,	Weight = -2.34453226,	Cost function = -16.65618328
#
# Epoch 3:	Bias = 19.5144046,	Weight = 5.3317103,	Cost function = 0.36175255
# DIFF:		Bias = 2.28582114,	Weight = 0.57927813,	Cost function = -1.60670065
#
# Epoch 4:	Bias = 18.85010456,	Weight = 5.01064039,	Cost function = 0.19845845
# DIFF:		Bias = -0.66430004,	Weight = -0.3210699,	Cost function = -0.1632941
#
# Epoch 5:	Bias = 19.09777138,	Weight = 4.97310812,	Cost function = 0.17415249
# DIFF:		Bias = 0.24766682,	Weight = -0.03753227,	Cost function = -0.02430596
#
# Epoch 6:	Bias = 19.06165865,	Weight = 4.85239348,	Cost function = 0.16374332
# DIFF:		Bias = -0.03611273,	Weight = -0.12071464,	Cost function = -0.01040917
#
# Epoch 7:	Bias = 19.11204582,	Weight = 4.76188681,	Cost function = 0.15520091
# DIFF:		Bias = 0.05038717,	Weight = -0.09050668,	Cost function = -0.00854241
#
# Epoch 8:	Bias = 19.13433138,	Weight = 4.66632988,	Cost function = 0.14733663
# DIFF:		Bias = 0.02228556,	Weight = -0.09555692,	Cost function = -0.00786429
#
# Epoch 9:	Bias = 19.16404311,	Weight = 4.57649473,	Cost function = 0.14000349
# DIFF:		Bias = 0.02971173,	Weight = -0.08983515,	Cost function = -0.00733314
#
# Epoch 10:	Bias = 19.19022364,	Weight = 4.48890617,	Cost function = 0.13315656
# DIFF:		Bias = 0.02618053,	Weight = -0.08758856,	Cost function = -0.00684693
#
# Epoch 11:	Bias = 19.21630708,	Weight = 4.40450499,	Cost function = 0.12676273
# DIFF:		Bias = 0.02608344,	Weight = -0.08440118,	Cost function = -0.00639383
#
# Epoch 12:	Bias = 19.2412702,	Weight = 4.32286926,	Cost function = 0.12079194
# DIFF:		Bias = 0.02496313,	Weight = -0.08163573,	Cost function = -0.00597079
#
# Epoch 13:	Bias = 19.26546854,	Weight = 4.24400336,	Cost function = 0.11521619
# DIFF:		Bias = 0.02419833,	Weight = -0.0788659,	Cost function = -0.00557575
#
# Epoch 14:	Bias = 19.28882941,	Weight = 4.16778392,	Cost function = 0.11000934
# DIFF:		Bias = 0.02336087,	Weight = -0.07621944,	Cost function = -0.00520685
#
# Epoch 15:	Bias = 19.31141146,	Weight = 4.09413125,	Cost function = 0.10514699
# DIFF:		Bias = 0.02258205,	Weight = -0.07365267,	Cost function = -0.00486235
#
# Epoch 16:	Bias = 19.33323146,	Weight = 4.02295608,	Cost function = 0.10060634
# DIFF:		Bias = 0.02182,	Weight = -0.07117517,	Cost function = -0.00454065
#
# Epoch 17:	Bias = 19.35431797,	Weight = 3.95417595,	Cost function = 0.09636611
# DIFF:		Bias = 0.02108651,	Weight = -0.06878013,	Cost function = -0.00424023
#
# Epoch 18:	Bias = 19.37469477,	Weight = 3.88771,	Cost function = 0.09240642
# DIFF:		Bias = 0.0203768,	Weight = -0.06646595,	Cost function = -0.00395969
#
# Epoch 19:	Bias = 19.39438603,	Weight = 3.82348045,	Cost function = 0.08870871
# DIFF:		Bias = 0.01969125,	Weight = -0.06422955,	Cost function = -0.00369771
#
# Epoch 20:	Bias = 19.4134147,	Weight = 3.76141203,	Cost function = 0.08525564
# DIFF:		Bias = 0.01902868,	Weight = -0.06206843,	Cost function = -0.00345306
#
# Epoch 21:	Bias = 19.43180313,	Weight = 3.70143202,	Cost function = 0.08203104
# DIFF:		Bias = 0.01838843,	Weight = -0.05998001,	Cost function = -0.0032246
#
# Epoch 22:	Bias = 19.44957285,	Weight = 3.64347015,	Cost function = 0.07901978
# DIFF:		Bias = 0.01776971,	Weight = -0.05796186,	Cost function = -0.00301126
#
# Epoch 23:	Bias = 19.46674466,	Weight = 3.58745853,	Cost function = 0.07620776
# DIFF:		Bias = 0.01717182,	Weight = -0.05601162,	Cost function = -0.00281203
#
# Epoch 24:	Bias = 19.4833387,	Weight = 3.53333153,	Cost function = 0.07358178
# DIFF:		Bias = 0.01659404,	Weight = -0.054127,	Cost function = -0.00262598
#
# Epoch 25:	Bias = 19.49937439,	Weight = 3.48102574,	Cost function = 0.07112954
# DIFF:		Bias = 0.0160357,	Weight = -0.05230579,	Cost function = -0.00245224
#
# Epoch 26:	Bias = 19.51487054,	Weight = 3.43047988,	Cost function = 0.06883955
# DIFF:		Bias = 0.01549614,	Weight = -0.05054586,	Cost function = -0.00228999
#
# Epoch 27:	Bias = 19.52984528,	Weight = 3.38163473,	Cost function = 0.06670106
# DIFF:		Bias = 0.01497475,	Weight = -0.04884514,	Cost function = -0.00213848
#
# Epoch 28:	Bias = 19.54431617,	Weight = 3.33443308,	Cost function = 0.06470406
# DIFF:		Bias = 0.01447089,	Weight = -0.04720165,	Cost function = -0.001997
#
# Epoch 29:	Bias = 19.55830016,	Weight = 3.28881962,	Cost function = 0.06283919
# DIFF:		Bias = 0.01398399,	Weight = -0.04561346,	Cost function = -0.00186487
#
# Epoch 30:	Bias = 19.57181363,	Weight = 3.24474091,	Cost function = 0.0610977
# DIFF:		Bias = 0.01351347,	Weight = -0.0440787,	Cost function = -0.00174149
#
# Epoch 31:	Bias = 19.58487241,	Weight = 3.20214532,	Cost function = 0.05947143
# DIFF:		Bias = 0.01305878,	Weight = -0.04259559,	Cost function = -0.00162627
#
# Epoch 32:	Bias = 19.59749181,	Weight = 3.16098295,	Cost function = 0.05795276
# DIFF:		Bias = 0.01261939,	Weight = -0.04116238,	Cost function = -0.00151867
#
# Epoch 33:	Bias = 19.6096866,	Weight = 3.12120556,	Cost function = 0.05653457
# DIFF:		Bias = 0.01219479,	Weight = -0.03977739,	Cost function = -0.00141819
#
# Epoch 34:	Bias = 19.62147107,	Weight = 3.08276656,	Cost function = 0.0552102
# DIFF:		Bias = 0.01178447,	Weight = -0.038439,	Cost function = -0.00132436
#
# Epoch 35:	Bias = 19.63285903,	Weight = 3.04562092,	Cost function = 0.05397346
# DIFF:		Bias = 0.01138796,	Weight = -0.03714564,	Cost function = -0.00123674
#
# Epoch 36:	Bias = 19.64386382,	Weight = 3.00972511,	Cost function = 0.05281855
# DIFF:		Bias = 0.01100479,	Weight = -0.0358958,	Cost function = -0.00115492
#
# Epoch 37:	Bias = 19.65449833,	Weight = 2.9750371,	Cost function = 0.05174004
# DIFF:		Bias = 0.01063451,	Weight = -0.03468802,	Cost function = -0.0010785
#
# Epoch 38:	Bias = 19.66477502,	Weight = 2.94151622,	Cost function = 0.05073289
# DIFF:		Bias = 0.01027669,	Weight = -0.03352087,	Cost function = -0.00100715
#
# Epoch 39:	Bias = 19.67470593,	Weight = 2.90912323,	Cost function = 0.04979238
# DIFF:		Bias = 0.00993091,	Weight = -0.032393,	Cost function = -0.00094051
#
# Epoch 40:	Bias = 19.6843027,	Weight = 2.87782016,	Cost function = 0.04891409
# DIFF:		Bias = 0.00959677,	Weight = -0.03130307,	Cost function = -0.00087829
#
# Epoch 41:	Bias = 19.69357657,	Weight = 2.84757034,	Cost function = 0.04809391
# DIFF:		Bias = 0.00927387,	Weight = -0.03024982,	Cost function = -0.00082018
#
# Epoch 42:	Bias = 19.70253839,	Weight = 2.81833834,	Cost function = 0.047328
# DIFF:		Bias = 0.00896183,	Weight = -0.029232,	Cost function = -0.00076591
#
# Epoch 43:	Bias = 19.71119868,	Weight = 2.79008991,	Cost function = 0.04661276
# DIFF:		Bias = 0.00866029,	Weight = -0.02824843,	Cost function = -0.00071524
#
# Epoch 44:	Bias = 19.71956758,	Weight = 2.76279195,	Cost function = 0.04594484
# DIFF:		Bias = 0.0083689,	Weight = -0.02729796,	Cost function = -0.00066792
#
# Epoch 45:	Bias = 19.72765489,	Weight = 2.73641249,	Cost function = 0.04532111
# DIFF:		Bias = 0.00808731,	Weight = -0.02637946,	Cost function = -0.00062373
#
# Epoch 46:	Bias = 19.73547008,	Weight = 2.71092061,	Cost function = 0.04473865
# DIFF:		Bias = 0.0078152,	Weight = -0.02549188,	Cost function = -0.00058246
#
# Epoch 47:	Bias = 19.74302232,	Weight = 2.68628646,	Cost function = 0.04419473
# DIFF:		Bias = 0.00755224,	Weight = -0.02463415,	Cost function = -0.00054392
#
# Epoch 48:	Bias = 19.75032045,	Weight = 2.66248117,	Cost function = 0.04368679
# DIFF:		Bias = 0.00729813,	Weight = -0.02380529,	Cost function = -0.00050794
#
# Epoch 49:	Bias = 19.75737302,	Weight = 2.63947686,	Cost function = 0.04321246
# DIFF:		Bias = 0.00705257,	Weight = -0.02300431,	Cost function = -0.00047433
#
# Epoch 50:	Bias = 19.76418829,	Weight = 2.61724658,	Cost function = 0.04276951
# DIFF:		Bias = 0.00681527,	Weight = -0.02223028,	Cost function = -0.00044295
#
# Epoch 51:	Bias = 19.77077424,	Weight = 2.59576427,	Cost function = 0.04235587
# DIFF:		Bias = 0.00658596,	Weight = -0.0214823,	Cost function = -0.00041364
#
# Epoch 52:	Bias = 19.7771386,	Weight = 2.57500479,	Cost function = 0.04196959
# DIFF:		Bias = 0.00636436,	Weight = -0.02075949,	Cost function = -0.00038627
#
# Epoch 53:	Bias = 19.78328882,	Weight = 2.55494379,	Cost function = 0.04160887
# DIFF:		Bias = 0.00615022,	Weight = -0.02006099,	Cost function = -0.00036072
#
# Epoch 54:	Bias = 19.7892321,	Weight = 2.53555779,	Cost function = 0.04127202
# DIFF:		Bias = 0.00594328,	Weight = -0.019386,	Cost function = -0.00033685
#
# Epoch 55:	Bias = 19.79497541,	Weight = 2.51682407,	Cost function = 0.04095746
# DIFF:		Bias = 0.00574331,	Weight = -0.01873372,	Cost function = -0.00031457
#
# Epoch 56:	Bias = 19.80052547,	Weight = 2.49872068,	Cost function = 0.0406637
# DIFF:		Bias = 0.00555006,	Weight = -0.01810339,	Cost function = -0.00029375
#
# Epoch 57:	Bias = 19.80588879,	Weight = 2.48122641,	Cost function = 0.04038938
# DIFF:		Bias = 0.00536332,	Weight = -0.01749426,	Cost function = -0.00027432
#
# Epoch 58:	Bias = 19.81107166,	Weight = 2.46432078,	Cost function = 0.04013322
# DIFF:		Bias = 0.00518286,	Weight = -0.01690564,	Cost function = -0.00025617
#
# Epoch 59:	Bias = 19.81608013,	Weight = 2.44798397,	Cost function = 0.039894
# DIFF:		Bias = 0.00500847,	Weight = -0.01633681,	Cost function = -0.00023922
#
# Epoch 60:	Bias = 19.82092008,	Weight = 2.43219684,	Cost function = 0.0396706
# DIFF:		Bias = 0.00483995,	Weight = -0.01578713,	Cost function = -0.00022339
#
# Epoch 61:	Bias = 19.82559719,	Weight = 2.4169409,	Cost function = 0.03946199
# DIFF:		Bias = 0.0046771,	Weight = -0.01525594,	Cost function = -0.00020861
#
# Epoch 62:	Bias = 19.83011692,	Weight = 2.40219828,	Cost function = 0.03926718
# DIFF:		Bias = 0.00451973,	Weight = -0.01474262,	Cost function = -0.00019481
#
# Epoch 63:	Bias = 19.83448458,	Weight = 2.3879517,	Cost function = 0.03908526
# DIFF:		Bias = 0.00436766,	Weight = -0.01424658,	Cost function = -0.00018192
#
# Epoch 64:	Bias = 19.83870528,	Weight = 2.37418447,	Cost function = 0.03891537
# DIFF:		Bias = 0.0042207,	Weight = -0.01376722,	Cost function = -0.00016989
#
# Epoch 65:	Bias = 19.84278396,	Weight = 2.36088048,	Cost function = 0.03875673
# DIFF:		Bias = 0.00407869,	Weight = -0.013304,	Cost function = -0.00015865
#
# Epoch 66:	Bias = 19.84672541,	Weight = 2.34802412,	Cost function = 0.03860858
# DIFF:		Bias = 0.00394145,	Weight = -0.01285636,	Cost function = -0.00014815
#
# Epoch 67:	Bias = 19.85053424,	Weight = 2.33560034,	Cost function = 0.03847023
# DIFF:		Bias = 0.00380883,	Weight = -0.01242378,	Cost function = -0.00013835
#
# Epoch 68:	Bias = 19.85421492,	Weight = 2.32359458,	Cost function = 0.03834104
# DIFF:		Bias = 0.00368068,	Weight = -0.01200576,	Cost function = -0.00012919
#
# Epoch 69:	Bias = 19.85777175,	Weight = 2.31199278,	Cost function = 0.03822039
# DIFF:		Bias = 0.00355683,	Weight = -0.0116018,	Cost function = -0.00012065
#
# Epoch 70:	Bias = 19.86120891,	Weight = 2.30078134,	Cost function = 0.03810773
# DIFF:		Bias = 0.00343716,	Weight = -0.01121144,	Cost function = -0.00011266
#
# Epoch 71:	Bias = 19.86453042,	Weight = 2.28994714,	Cost function = 0.03800252
# DIFF:		Bias = 0.00332151,	Weight = -0.0108342,	Cost function = -0.00010521
#
# Epoch 72:	Bias = 19.86774016,	Weight = 2.27947747,	Cost function = 0.03790427
# DIFF:		Bias = 0.00320975,	Weight = -0.01046967,	Cost function = -9.825e-05
#
# Epoch 73:	Bias = 19.87084191,	Weight = 2.26936008,	Cost function = 0.03781252
# DIFF:		Bias = 0.00310175,	Weight = -0.01011739,	Cost function = -9.175e-05
#
# Epoch 74:	Bias = 19.8738393,	Weight = 2.2595831,	Cost function = 0.03772684
# DIFF:		Bias = 0.00299738,	Weight = -0.00977697,	Cost function = -8.568e-05
#
# Epoch 75:	Bias = 19.87673583,	Weight = 2.25013509,	Cost function = 0.03764683
# DIFF:		Bias = 0.00289653,	Weight = -0.00944801,	Cost function = -8.001e-05
#
# Epoch 76:	Bias = 19.8795349,	Weight = 2.24100498,	Cost function = 0.03757211
# DIFF:		Bias = 0.00279907,	Weight = -0.00913011,	Cost function = -7.472e-05
#
# Epoch 77:	Bias = 19.88223979,	Weight = 2.23218207,	Cost function = 0.03750234
# DIFF:		Bias = 0.00270489,	Weight = -0.00882291,	Cost function = -6.977e-05
#
# Epoch 78:	Bias = 19.88485368,	Weight = 2.22365602,	Cost function = 0.03743718
# DIFF:		Bias = 0.00261388,	Weight = -0.00852605,	Cost function = -6.516e-05
#
# Epoch 79:	Bias = 19.88737961,	Weight = 2.21541685,	Cost function = 0.03737634
# DIFF:		Bias = 0.00252593,	Weight = -0.00823917,	Cost function = -6.085e-05
#
# Epoch 80:	Bias = 19.88982055,	Weight = 2.20745491,	Cost function = 0.03731952
# DIFF:		Bias = 0.00244094,	Weight = -0.00796195,	Cost function = -5.682e-05
#
# Epoch 81:	Bias = 19.89217936,	Weight = 2.19976085,	Cost function = 0.03726646
# DIFF:		Bias = 0.00235881,	Weight = -0.00769405,	Cost function = -5.306e-05
#
# Epoch 82:	Bias = 19.8944588,	Weight = 2.19232568,	Cost function = 0.03721691
# DIFF:		Bias = 0.00227944,	Weight = -0.00743517,	Cost function = -4.955e-05
#
# Epoch 83:	Bias = 19.89666155,	Weight = 2.18514068,	Cost function = 0.03717064
# DIFF:		Bias = 0.00220275,	Weight = -0.007185,	Cost function = -4.627e-05
#
# Epoch 84:	Bias = 19.89879018,	Weight = 2.17819744,	Cost function = 0.03712743
# DIFF:		Bias = 0.00212863,	Weight = -0.00694325,	Cost function = -4.321e-05
#
# Epoch 85:	Bias = 19.90084719,	Weight = 2.17148781,	Cost function = 0.03708707
# DIFF:		Bias = 0.00205701,	Weight = -0.00670963,	Cost function = -4.035e-05
#
# Epoch 86:	Bias = 19.90283499,	Weight = 2.16500394,	Cost function = 0.03704939
# DIFF:		Bias = 0.0019878,	Weight = -0.00648387,	Cost function = -3.768e-05
#
# Epoch 87:	Bias = 19.90475591,	Weight = 2.15873823,	Cost function = 0.0370142
# DIFF:		Bias = 0.00192091,	Weight = -0.00626571,	Cost function = -3.519e-05
#
# Epoch 88:	Bias = 19.90661219,	Weight = 2.15268335,	Cost function = 0.03698134
# DIFF:		Bias = 0.00185628,	Weight = -0.00605488,	Cost function = -3.286e-05
#
# Epoch 89:	Bias = 19.90840601,	Weight = 2.1468322,	Cost function = 0.03695066
# DIFF:		Bias = 0.00179382,	Weight = -0.00585116,	Cost function = -3.069e-05
#
# Epoch 90:	Bias = 19.91013948,	Weight = 2.14117791,	Cost function = 0.036922
# DIFF:		Bias = 0.00173347,	Weight = -0.00565428,	Cost function = -2.866e-05
#
# Epoch 91:	Bias = 19.91181462,	Weight = 2.13571388,	Cost function = 0.03689524
# DIFF:		Bias = 0.00167514,	Weight = -0.00546403,	Cost function = -2.676e-05
#
# Epoch 92:	Bias = 19.9134334,	Weight = 2.1304337,	Cost function = 0.03687025
# DIFF:		Bias = 0.00161878,	Weight = -0.00528018,	Cost function = -2.499e-05
#
# Epoch 93:	Bias = 19.91499771,	Weight = 2.12533118,	Cost function = 0.03684691
# DIFF:		Bias = 0.00156431,	Weight = -0.00510252,	Cost function = -2.334e-05
#
# Epoch 94:	Bias = 19.91650938,	Weight = 2.12040034,	Cost function = 0.03682512
# DIFF:		Bias = 0.00151168,	Weight = -0.00493084,	Cost function = -2.179e-05
#
# Epoch 95:	Bias = 19.91797019,	Weight = 2.11563541,	Cost function = 0.03680477
# DIFF:		Bias = 0.00146081,	Weight = -0.00476493,	Cost function = -2.035e-05
#
# Epoch 96:	Bias = 19.91938186,	Weight = 2.11103081,	Cost function = 0.03678577
# DIFF:		Bias = 0.00141166,	Weight = -0.0046046,	Cost function = -1.9e-05
#
# Epoch 97:	Bias = 19.92074602,	Weight = 2.10658113,	Cost function = 0.03676802
# DIFF:		Bias = 0.00136416,	Weight = -0.00444967,	Cost function = -1.775e-05
#
# Epoch 98:	Bias = 19.92206428,	Weight = 2.10228118,	Cost function = 0.03675145
# DIFF:		Bias = 0.00131826,	Weight = -0.00429995,	Cost function = -1.657e-05
#
# Epoch 99:	Bias = 19.92333819,	Weight = 2.0981259,	Cost function = 0.03673597
# DIFF:		Bias = 0.00127391,	Weight = -0.00415527,	Cost function = -1.548e-05
#
# Epoch 100:	Bias = 19.92456923,	Weight = 2.09411044,	Cost function = 0.03672152
# DIFF:		Bias = 0.00123104,	Weight = -0.00401546,	Cost function = -1.445e-05
#
# Epoch 101:	Bias = 19.92575886,	Weight = 2.09023009,	Cost function = 0.03670802
# DIFF:		Bias = 0.00118962,	Weight = -0.00388035,	Cost function = -1.35e-05
#
# Epoch 102:	Bias = 19.92690845,	Weight = 2.0864803,	Cost function = 0.03669542
# DIFF:		Bias = 0.0011496,	Weight = -0.00374979,	Cost function = -1.26e-05
#
# Epoch 103:	Bias = 19.92801937,	Weight = 2.08285667,	Cost function = 0.03668365
# DIFF:		Bias = 0.00111092,	Weight = -0.00362362,	Cost function = -1.177e-05
#
# Epoch 104:	Bias = 19.9290929,	Weight = 2.07935497,	Cost function = 0.03667266
# DIFF:		Bias = 0.00107354,	Weight = -0.0035017,	Cost function = -1.099e-05
#
# Epoch 105:	Bias = 19.93013032,	Weight = 2.0759711,	Cost function = 0.0366624
# DIFF:		Bias = 0.00103742,	Weight = -0.00338388,	Cost function = -1.026e-05
#
# Epoch 106:	Bias = 19.93113283,	Weight = 2.07270108,	Cost function = 0.03665281
# DIFF:		Bias = 0.00100251,	Weight = -0.00327002,	Cost function = -9.58e-06
#
# Epoch 107:	Bias = 19.93210161,	Weight = 2.06954108,	Cost function = 0.03664386
# DIFF:		Bias = 0.00096878,	Weight = -0.00315999,	Cost function = -8.95e-06
#
# Epoch 108:	Bias = 19.93303779,	Weight = 2.06648742,	Cost function = 0.0366355
# DIFF:		Bias = 0.00093618,	Weight = -0.00305367,	Cost function = -8.36e-06
#
# Epoch 109:	Bias = 19.93394247,	Weight = 2.06353649,	Cost function = 0.0366277
# DIFF:		Bias = 0.00090468,	Weight = -0.00295092,	Cost function = -7.81e-06
#
# Epoch 110:	Bias = 19.93481671,	Weight = 2.06068486,	Cost function = 0.03662041
# DIFF:		Bias = 0.00087424,	Weight = -0.00285163,	Cost function = -7.29e-06
#
# Epoch 111:	Bias = 19.93566154,	Weight = 2.05792918,	Cost function = 0.0366136
# DIFF:		Bias = 0.00084483,	Weight = -0.00275568,	Cost function = -6.81e-06
#
# Epoch 112:	Bias = 19.93647794,	Weight = 2.05526621,	Cost function = 0.03660725
# DIFF:		Bias = 0.0008164,	Weight = -0.00266296,	Cost function = -6.36e-06
#
# Epoch 113:	Bias = 19.93726687,	Weight = 2.05269285,	Cost function = 0.03660131
# DIFF:		Bias = 0.00078893,	Weight = -0.00257336,	Cost function = -5.94e-06
#
# Epoch 114:	Bias = 19.93802926,	Weight = 2.05020607,	Cost function = 0.03659577
# DIFF:		Bias = 0.00076239,	Weight = -0.00248678,	Cost function = -5.54e-06
#
# Epoch 115:	Bias = 19.93876599,	Weight = 2.04780297,	Cost function = 0.03659059
# DIFF:		Bias = 0.00073673,	Weight = -0.0024031,	Cost function = -5.18e-06
#
# Epoch 116:	Bias = 19.93947793,	Weight = 2.04548072,	Cost function = 0.03658576
# DIFF:		Bias = 0.00071195,	Weight = -0.00232225,	Cost function = -4.83e-06
#
# Epoch 117:	Bias = 19.94016592,	Weight = 2.04323661,	Cost function = 0.03658125
# DIFF:		Bias = 0.00068799,	Weight = -0.00224411,	Cost function = -4.51e-06
#
# Epoch 118:	Bias = 19.94083077,	Weight = 2.04106801,	Cost function = 0.03657703
# DIFF:		Bias = 0.00066484,	Weight = -0.0021686,	Cost function = -4.22e-06
#
# Epoch 119:	Bias = 19.94147324,	Weight = 2.03897237,	Cost function = 0.03657309
# DIFF:		Bias = 0.00064247,	Weight = -0.00209564,	Cost function = -3.94e-06
#
# Epoch 120:	Bias = 19.94209409,	Weight = 2.03694724,	Cost function = 0.03656942
# DIFF:		Bias = 0.00062085,	Weight = -0.00202512,	Cost function = -3.68e-06
#
# Epoch 121:	Bias = 19.94269406,	Weight = 2.03499026,	Cost function = 0.03656598
# DIFF:		Bias = 0.00059996,	Weight = -0.00195699,	Cost function = -3.43e-06
#
# Epoch 122:	Bias = 19.94327383,	Weight = 2.03309912,	Cost function = 0.03656278
# DIFF:		Bias = 0.00057978,	Weight = -0.00189114,	Cost function = -3.21e-06
#
# Epoch 123:	Bias = 19.9438341,	Weight = 2.03127161,	Cost function = 0.03655979
# DIFF:		Bias = 0.00056027,	Weight = -0.00182751,	Cost function = -2.99e-06
#
# Epoch 124:	Bias = 19.94437552,	Weight = 2.0295056,	Cost function = 0.03655699
# DIFF:		Bias = 0.00054142,	Weight = -0.00176602,	Cost function = -2.8e-06
#
# Epoch 125:	Bias = 19.94489872,	Weight = 2.027799,	Cost function = 0.03655438
# DIFF:		Bias = 0.0005232,	Weight = -0.0017066,	Cost function = -2.61e-06
#
# Epoch 126:	Bias = 19.94540432,	Weight = 2.02614983,	Cost function = 0.03655194
# DIFF:		Bias = 0.0005056,	Weight = -0.00164917,	Cost function = -2.44e-06
#
# Epoch 127:	Bias = 19.94589291,	Weight = 2.02455614,	Cost function = 0.03654967
# DIFF:		Bias = 0.00048859,	Weight = -0.00159368,	Cost function = -2.28e-06
#
# Epoch 128:	Bias = 19.94636505,	Weight = 2.02301608,	Cost function = 0.03654754
# DIFF:		Bias = 0.00047215,	Weight = -0.00154006,	Cost function = -2.13e-06
#
# Epoch 129:	Bias = 19.94682131,	Weight = 2.02152784,	Cost function = 0.03654555
# DIFF:		Bias = 0.00045626,	Weight = -0.00148824,	Cost function = -1.99e-06
#
# Epoch 130:	Bias = 19.94726222,	Weight = 2.02008967,	Cost function = 0.0365437
# DIFF:		Bias = 0.00044091,	Weight = -0.00143817,	Cost function = -1.85e-06
#
# Epoch 131:	Bias = 19.94768829,	Weight = 2.01869989,	Cost function = 0.03654197
# DIFF:		Bias = 0.00042607,	Weight = -0.00138978,	Cost function = -1.73e-06
#
# Epoch 132:	Bias = 19.94810003,	Weight = 2.01735687,	Cost function = 0.03654035
# DIFF:		Bias = 0.00041174,	Weight = -0.00134302,	Cost function = -1.62e-06
#
# Epoch 133:	Bias = 19.94849791,	Weight = 2.01605904,	Cost function = 0.03653884
# DIFF:		Bias = 0.00039788,	Weight = -0.00129783,	Cost function = -1.51e-06
#
# Epoch 134:	Bias = 19.94888241,	Weight = 2.01480488,	Cost function = 0.03653743
# DIFF:		Bias = 0.0003845,	Weight = -0.00125416,	Cost function = -1.41e-06
#
# Epoch 135:	Bias = 19.94925397,	Weight = 2.01359292,	Cost function = 0.03653612
# DIFF:		Bias = 0.00037156,	Weight = -0.00121196,	Cost function = -1.32e-06
#
# Epoch 136:	Bias = 19.94961302,	Weight = 2.01242174,	Cost function = 0.03653489
# DIFF:		Bias = 0.00035906,	Weight = -0.00117118,	Cost function = -1.23e-06
#
# Epoch 137:	Bias = 19.94996,	Weight = 2.01128996,	Cost function = 0.03653374
# DIFF:		Bias = 0.00034698,	Weight = -0.00113178,	Cost function = -1.15e-06
#
# Epoch 138:	Bias = 19.9502953,	Weight = 2.01019627,	Cost function = 0.03653267
# DIFF:		Bias = 0.0003353,	Weight = -0.0010937,	Cost function = -1.07e-06
#
# Epoch 139:	Bias = 19.95061932,	Weight = 2.00913937,	Cost function = 0.03653167
# DIFF:		Bias = 0.00032402,	Weight = -0.0010569,	Cost function = -1e-06
#
# Epoch 140:	Bias = 19.95093243,	Weight = 2.00811804,	Cost function = 0.03653073
# DIFF:		Bias = 0.00031312,	Weight = -0.00102133,	Cost function = -9.3e-07
#
# Epoch 141:	Bias = 19.95123501,	Weight = 2.00713107,	Cost function = 0.03652986
# DIFF:		Bias = 0.00030258,	Weight = -0.00098697,	Cost function = -8.7e-07
#
# Epoch 142:	Bias = 19.95152741,	Weight = 2.00617731,	Cost function = 0.03652904
# DIFF:		Bias = 0.0002924,	Weight = -0.00095376,	Cost function = -8.2e-07
#
# Epoch 143:	Bias = 19.95180998,	Weight = 2.00525564,	Cost function = 0.03652828
# DIFF:		Bias = 0.00028256,	Weight = -0.00092167,	Cost function = -7.6e-07
#
# Epoch 144:	Bias = 19.95208303,	Weight = 2.00436498,	Cost function = 0.03652757
# DIFF:		Bias = 0.00027305,	Weight = -0.00089066,	Cost function = -7.1e-07
#
# Epoch 145:	Bias = 19.9523469,	Weight = 2.00350429,	Cost function = 0.03652691
# DIFF:		Bias = 0.00026387,	Weight = -0.00086069,	Cost function = -6.6e-07
#
# Epoch 146:	Bias = 19.95260189,	Weight = 2.00267256,	Cost function = 0.03652629
# DIFF:		Bias = 0.00025499,	Weight = -0.00083173,	Cost function = -6.2e-07
#
# Epoch 147:	Bias = 19.9528483,	Weight = 2.00186881,	Cost function = 0.03652571
# DIFF:		Bias = 0.00024641,	Weight = -0.00080375,	Cost function = -5.8e-07
#
# Epoch 148:	Bias = 19.95308641,	Weight = 2.00109211,	Cost function = 0.03652517
# DIFF:		Bias = 0.00023812,	Weight = -0.0007767,	Cost function = -5.4e-07
#
# Epoch 149:	Bias = 19.95331652,	Weight = 2.00034154,	Cost function = 0.03652466
# DIFF:		Bias = 0.00023011,	Weight = -0.00075057,	Cost function = -5e-07
#
# Epoch 150:	Bias = 19.95353888,	Weight = 1.99961623,	Cost function = 0.03652419
# DIFF:		Bias = 0.00022236,	Weight = -0.00072531,	Cost function = -4.7e-07
#
# Epoch 151:	Bias = 19.95375377,	Weight = 1.99891532,	Cost function = 0.03652375
# DIFF:		Bias = 0.00021488,	Weight = -0.00070091,	Cost function = -4.4e-07
#
# Epoch 152:	Bias = 19.95396142,	Weight = 1.99823799,	Cost function = 0.03652334
# DIFF:		Bias = 0.00020765,	Weight = -0.00067733,	Cost function = -4.1e-07
#
# Epoch 153:	Bias = 19.95416208,	Weight = 1.99758346,	Cost function = 0.03652295
# DIFF:		Bias = 0.00020066,	Weight = -0.00065454,	Cost function = -3.8e-07
#
# Epoch 154:	Bias = 19.954356,	Weight = 1.99695094,	Cost function = 0.0365226
# DIFF:		Bias = 0.00019391,	Weight = -0.00063251,	Cost function = -3.6e-07
#
# Epoch 155:	Bias = 19.95454338,	Weight = 1.99633971,	Cost function = 0.03652226
# DIFF:		Bias = 0.00018739,	Weight = -0.00061123,	Cost function = -3.3e-07
#
# Epoch 156:	Bias = 19.95472447,	Weight = 1.99574905,	Cost function = 0.03652195
# DIFF:		Bias = 0.00018108,	Weight = -0.00059066,	Cost function = -3.1e-07
#
# Epoch 157:	Bias = 19.95489946,	Weight = 1.99517826,	Cost function = 0.03652166
# DIFF:		Bias = 0.00017499,	Weight = -0.00057079,	Cost function = -2.9e-07
#
# Epoch 158:	Bias = 19.95506856,	Weight = 1.99462667,	Cost function = 0.03652138
# DIFF:		Bias = 0.0001691,	Weight = -0.00055159,	Cost function = -2.7e-07
#
# Epoch 159:	Bias = 19.95523197,	Weight = 1.99409365,	Cost function = 0.03652113
# DIFF:		Bias = 0.00016341,	Weight = -0.00053303,	Cost function = -2.5e-07
#
# Epoch 160:	Bias = 19.95538989,	Weight = 1.99357856,	Cost function = 0.03652089
# DIFF:		Bias = 0.00015791,	Weight = -0.00051509,	Cost function = -2.4e-07
#
# Epoch 161:	Bias = 19.95554249,	Weight = 1.9930808,	Cost function = 0.03652067
# DIFF:		Bias = 0.0001526,	Weight = -0.00049776,	Cost function = -2.2e-07
#
# Epoch 162:	Bias = 19.95568996,	Weight = 1.99259978,	Cost function = 0.03652046
# DIFF:		Bias = 0.00014747,	Weight = -0.00048101,	Cost function = -2.1e-07
#
# Epoch 163:	Bias = 19.95583246,	Weight = 1.99213496,	Cost function = 0.03652027
# DIFF:		Bias = 0.0001425,	Weight = -0.00046483,	Cost function = -1.9e-07
#
# Epoch 164:	Bias = 19.95597017,	Weight = 1.99168577,	Cost function = 0.03652009
# DIFF:		Bias = 0.00013771,	Weight = -0.00044919,	Cost function = -1.8e-07
#
# Epoch 165:	Bias = 19.95610325,	Weight = 1.9912517,	Cost function = 0.03651992
# DIFF:		Bias = 0.00013308,	Weight = -0.00043407,	Cost function = -1.7e-07
#
# Epoch 166:	Bias = 19.95623185,	Weight = 1.99083223,	Cost function = 0.03651976
# DIFF:		Bias = 0.0001286,	Weight = -0.00041947,	Cost function = -1.6e-07
#
# Epoch 167:	Bias = 19.95635612,	Weight = 1.99042687,	Cost function = 0.03651961
# DIFF:		Bias = 0.00012427,	Weight = -0.00040535,	Cost function = -1.5e-07
#
# Epoch 168:	Bias = 19.95647621,	Weight = 1.99003516,	Cost function = 0.03651948
# DIFF:		Bias = 0.00012009,	Weight = -0.00039172,	Cost function = -1.4e-07
#
# Epoch 169:	Bias = 19.95659226,	Weight = 1.98965662,	Cost function = 0.03651935
# DIFF:		Bias = 0.00011605,	Weight = -0.00037854,	Cost function = -1.3e-07
#
# Epoch 170:	Bias = 19.9567044,	Weight = 1.98929082,	Cost function = 0.03651923
# DIFF:		Bias = 0.00011215,	Weight = -0.0003658,	Cost function = -1.2e-07
#
# Epoch 171:	Bias = 19.95681278,	Weight = 1.98893733,	Cost function = 0.03651911
# DIFF:		Bias = 0.00010837,	Weight = -0.00035349,	Cost function = -1.1e-07
#
# Epoch 172:	Bias = 19.9569175,	Weight = 1.98859574,	Cost function = 0.03651901
# DIFF:		Bias = 0.00010473,	Weight = -0.0003416,	Cost function = -1e-07
#
# Epoch 173:	Bias = 19.9570187,	Weight = 1.98826563,	Cost function = 0.03651891
# DIFF:		Bias = 0.0001012,	Weight = -0.0003301,	Cost function = -1e-07
#
# Epoch 174:	Bias = 19.9571165,	Weight = 1.98794664,	Cost function = 0.03651882
# DIFF:		Bias = 9.78e-05,	Weight = -0.000319,	Cost function = -9e-08
#
# Epoch 175:	Bias = 19.957211,	Weight = 1.98763837,	Cost function = 0.03651874
# DIFF:		Bias = 9.451e-05,	Weight = -0.00030826,	Cost function = -9e-08
#
# Epoch 176:	Bias = 19.95730233,	Weight = 1.98734048,	Cost function = 0.03651866
# DIFF:		Bias = 9.133e-05,	Weight = -0.00029789,	Cost function = -8e-08
#
# Epoch 177:	Bias = 19.95739058,	Weight = 1.98705262,	Cost function = 0.03651858
# DIFF:		Bias = 8.825e-05,	Weight = -0.00028787,	Cost function = -7e-08
#
# Epoch 178:	Bias = 19.95747587,	Weight = 1.98677443,	Cost function = 0.03651851
# DIFF:		Bias = 8.528e-05,	Weight = -0.00027818,	Cost function = -7e-08
#
# Epoch 179:	Bias = 19.95755828,	Weight = 1.98650561,	Cost function = 0.03651845
# DIFF:		Bias = 8.241e-05,	Weight = -0.00026882,	Cost function = -6e-08
#
# Epoch 180:	Bias = 19.95763792,	Weight = 1.98624584,	Cost function = 0.03651839
# DIFF:		Bias = 7.964e-05,	Weight = -0.00025978,	Cost function = -6e-08
#
# Epoch 181:	Bias = 19.95771489,	Weight = 1.9859948,	Cost function = 0.03651833
# DIFF:		Bias = 7.696e-05,	Weight = -0.00025104,	Cost function = -6e-08
#
# Epoch 182:	Bias = 19.95778926,	Weight = 1.98575221,	Cost function = 0.03651828
# DIFF:		Bias = 7.437e-05,	Weight = -0.00024259,	Cost function = -5e-08
#
# Epoch 183:	Bias = 19.95786113,	Weight = 1.98551778,	Cost function = 0.03651823
# DIFF:		Bias = 7.187e-05,	Weight = -0.00023443,	Cost function = -5e-08
#
# Epoch 184:	Bias = 19.95793058,	Weight = 1.98529124,	Cost function = 0.03651818
# DIFF:		Bias = 6.945e-05,	Weight = -0.00022654,	Cost function = -5e-08
#
# Epoch 185:	Bias = 19.95799769,	Weight = 1.98507233,	Cost function = 0.03651814
# DIFF:		Bias = 6.711e-05,	Weight = -0.00021892,	Cost function = -4e-08
#
# Epoch 186:	Bias = 19.95806255,	Weight = 1.98486078,	Cost function = 0.0365181
# DIFF:		Bias = 6.486e-05,	Weight = -0.00021155,	Cost function = -4e-08
#
# Epoch 187:	Bias = 19.95812522,	Weight = 1.98465634,	Cost function = 0.03651806
# DIFF:		Bias = 6.267e-05,	Weight = -0.00020443,	Cost function = -4e-08
#
# Epoch 188:	Bias = 19.95818579,	Weight = 1.98445879,	Cost function = 0.03651803
# DIFF:		Bias = 6.057e-05,	Weight = -0.00019755,	Cost function = -3e-08
#
# Epoch 189:	Bias = 19.95824432,	Weight = 1.98426788,	Cost function = 0.03651799
# DIFF:		Bias = 5.853e-05,	Weight = -0.00019091,	Cost function = -3e-08
#
# Epoch 190:	Bias = 19.95830088,	Weight = 1.9840834,	Cost function = 0.03651796
# DIFF:		Bias = 5.656e-05,	Weight = -0.00018448,	Cost function = -3e-08
#
# Epoch 191:	Bias = 19.95835553,	Weight = 1.98390512,	Cost function = 0.03651794
# DIFF:		Bias = 5.466e-05,	Weight = -0.00017828,	Cost function = -3e-08
#
# Epoch 192:	Bias = 19.95840835,	Weight = 1.98373284,	Cost function = 0.03651791
# DIFF:		Bias = 5.282e-05,	Weight = -0.00017228,	Cost function = -3e-08
#
# Epoch 193:	Bias = 19.95845939,	Weight = 1.98356636,	Cost function = 0.03651788
# DIFF:		Bias = 5.104e-05,	Weight = -0.00016648,	Cost function = -2e-08
#
# Epoch 194:	Bias = 19.95850871,	Weight = 1.98340548,	Cost function = 0.03651786
# DIFF:		Bias = 4.932e-05,	Weight = -0.00016088,	Cost function = -2e-08
#
# Epoch 195:	Bias = 19.95855637,	Weight = 1.98325001,	Cost function = 0.03651784
# DIFF:		Bias = 4.766e-05,	Weight = -0.00015547,	Cost function = -2e-08
#
# Epoch 196:	Bias = 19.95860243,	Weight = 1.98309978,	Cost function = 0.03651782
# DIFF:		Bias = 4.606e-05,	Weight = -0.00015024,	Cost function = -2e-08
#
# Epoch 197:	Bias = 19.95864694,	Weight = 1.9829546,	Cost function = 0.0365178
# DIFF:		Bias = 4.451e-05,	Weight = -0.00014518,	Cost function = -2e-08
#
# Epoch 198:	Bias = 19.95868995,	Weight = 1.9828143,	Cost function = 0.03651778
# DIFF:		Bias = 4.301e-05,	Weight = -0.0001403,	Cost function = -2e-08
#
# Epoch 199:	Bias = 19.95873151,	Weight = 1.98267873,	Cost function = 0.03651777
# DIFF:		Bias = 4.156e-05,	Weight = -0.00013558,	Cost function = -2e-08
#
# Epoch 200:	Bias = 19.95877168,	Weight = 1.98254771,	Cost function = 0.03651775
# DIFF:		Bias = 4.017e-05,	Weight = -0.00013101,	Cost function = -2e-08
#
# Epoch 201:	Bias = 19.95881049,	Weight = 1.98242111,	Cost function = 0.03651774
# DIFF:		Bias = 3.881e-05,	Weight = -0.00012661,	Cost function = -1e-08
#
# Epoch 202:	Bias = 19.958848,	Weight = 1.98229876,	Cost function = 0.03651772
# DIFF:		Bias = 3.751e-05,	Weight = -0.00012235,	Cost function = -1e-08
#
# Epoch 203:	Bias = 19.95888425,	Weight = 1.98218053,	Cost function = 0.03651771
# DIFF:		Bias = 3.625e-05,	Weight = -0.00011823,	Cost function = -1e-08
#
# Epoch 204:	Bias = 19.95891927,	Weight = 1.98206628,	Cost function = 0.0365177
# DIFF:		Bias = 3.503e-05,	Weight = -0.00011425,	Cost function = -1e-08
#
# Epoch 205:	Bias = 19.95895312,	Weight = 1.98195587,	Cost function = 0.03651769
# DIFF:		Bias = 3.385e-05,	Weight = -0.00011041,	Cost function = -1e-08
#
# Epoch 206:	Bias = 19.95898583,	Weight = 1.98184918,	Cost function = 0.03651768
# DIFF:		Bias = 3.271e-05,	Weight = -0.00010669,	Cost function = -1e-08
#
# Epoch 207:	Bias = 19.95901744,	Weight = 1.98174608,	Cost function = 0.03651767
# DIFF:		Bias = 3.161e-05,	Weight = -0.0001031,	Cost function = -1e-08
#
# Epoch 208:	Bias = 19.95904799,	Weight = 1.98164645,	Cost function = 0.03651766
# DIFF:		Bias = 3.055e-05,	Weight = -9.963e-05,	Cost function = -1e-08
#
# Epoch 209:	Bias = 19.9590775,	Weight = 1.98155017,	Cost function = 0.03651765
# DIFF:		Bias = 2.952e-05,	Weight = -9.628e-05,	Cost function = -1e-08
#
# Epoch 210:	Bias = 19.95910603,	Weight = 1.98145713,	Cost function = 0.03651764
# DIFF:		Bias = 2.852e-05,	Weight = -9.304e-05,	Cost function = -1e-08
#
# Epoch 211:	Bias = 19.95913359,	Weight = 1.98136722,	Cost function = 0.03651764
# DIFF:		Bias = 2.756e-05,	Weight = -8.991e-05,	Cost function = -1e-08
#
# Epoch 212:	Bias = 19.95916023,	Weight = 1.98128033,	Cost function = 0.03651763
# DIFF:		Bias = 2.664e-05,	Weight = -8.689e-05,	Cost function = -1e-08
#
# Epoch 213:	Bias = 19.95918597,	Weight = 1.98119637,	Cost function = 0.03651762
# DIFF:		Bias = 2.574e-05,	Weight = -8.396e-05,	Cost function = -1e-08
#
# Epoch 214:	Bias = 19.95921084,	Weight = 1.98111523,	Cost function = 0.03651762
# DIFF:		Bias = 2.487e-05,	Weight = -8.114e-05,	Cost function = -1e-08
#
# Epoch 215:	Bias = 19.95923488,	Weight = 1.98103683,	Cost function = 0.03651761
# DIFF:		Bias = 2.404e-05,	Weight = -7.841e-05,	Cost function = -1e-08
#
# Epoch 216:	Bias = 19.95925811,	Weight = 1.98096106,	Cost function = 0.03651761
# DIFF:		Bias = 2.323e-05,	Weight = -7.577e-05,	Cost function = -1e-08
#
# Epoch 217:	Bias = 19.95928056,	Weight = 1.98088784,	Cost function = 0.0365176
# DIFF:		Bias = 2.245e-05,	Weight = -7.322e-05,	Cost function = -0.0
#
# Epoch 218:	Bias = 19.95930225,	Weight = 1.98081708,	Cost function = 0.0365176
# DIFF:		Bias = 2.169e-05,	Weight = -7.076e-05,	Cost function = -0.0
#
# Epoch 219:	Bias = 19.95932321,	Weight = 1.98074871,	Cost function = 0.03651759
# DIFF:		Bias = 2.096e-05,	Weight = -6.837e-05,	Cost function = -0.0
#
# Epoch 220:	Bias = 19.95934347,	Weight = 1.98068263,	Cost function = 0.03651759
# DIFF:		Bias = 2.026e-05,	Weight = -6.607e-05,	Cost function = -0.0
#
# Epoch 221:	Bias = 19.95936304,	Weight = 1.98061878,	Cost function = 0.03651759
# DIFF:		Bias = 1.958e-05,	Weight = -6.385e-05,	Cost function = -0.0
#
# Epoch 222:	Bias = 19.95938196,	Weight = 1.98055708,	Cost function = 0.03651758
# DIFF:		Bias = 1.892e-05,	Weight = -6.17e-05,	Cost function = -0.0
#
# Epoch 223:	Bias = 19.95940024,	Weight = 1.98049745,	Cost function = 0.03651758
# DIFF:		Bias = 1.828e-05,	Weight = -5.963e-05,	Cost function = -0.0
#
# Epoch 224:	Bias = 19.9594179,	Weight = 1.98043983,	Cost function = 0.03651758
# DIFF:		Bias = 1.767e-05,	Weight = -5.762e-05,	Cost function = -0.0
#
# Epoch 225:	Bias = 19.95943498,	Weight = 1.98038415,	Cost function = 0.03651757
# DIFF:		Bias = 1.707e-05,	Weight = -5.568e-05,	Cost function = -0.0
#
# Epoch 226:	Bias = 19.95945147,	Weight = 1.98033034,	Cost function = 0.03651757
# DIFF:		Bias = 1.65e-05,	Weight = -5.381e-05,	Cost function = -0.0
#
# Epoch 227:	Bias = 19.95946741,	Weight = 1.98027834,	Cost function = 0.03651757
# DIFF:		Bias = 1.594e-05,	Weight = -5.2e-05,	Cost function = -0.0
#
# Epoch 228:	Bias = 19.95948282,	Weight = 1.9802281,	Cost function = 0.03651757
# DIFF:		Bias = 1.54e-05,	Weight = -5.025e-05,	Cost function = -0.0
#
# Epoch 229:	Bias = 19.9594977,	Weight = 1.98017954,	Cost function = 0.03651756
# DIFF:		Bias = 1.489e-05,	Weight = -4.856e-05,	Cost function = -0.0
#
# Epoch 230:	Bias = 19.95951209,	Weight = 1.98013262,	Cost function = 0.03651756
# DIFF:		Bias = 1.439e-05,	Weight = -4.692e-05,	Cost function = -0.0
#
# Epoch 231:	Bias = 19.95952599,	Weight = 1.98008727,	Cost function = 0.03651756
# DIFF:		Bias = 1.39e-05,	Weight = -4.534e-05,	Cost function = -0.0
#
# Epoch 232:	Bias = 19.95953943,	Weight = 1.98004345,	Cost function = 0.03651756
# DIFF:		Bias = 1.343e-05,	Weight = -4.382e-05,	Cost function = -0.0
#
# Epoch 233:	Bias = 19.95955241,	Weight = 1.98000111,	Cost function = 0.03651756
# DIFF:		Bias = 1.298e-05,	Weight = -4.234e-05,	Cost function = -0.0
#
# Epoch 234:	Bias = 19.95956495,	Weight = 1.97996019,	Cost function = 0.03651756
# DIFF:		Bias = 1.255e-05,	Weight = -4.092e-05,	Cost function = -0.0
#
# Epoch 235:	Bias = 19.95957707,	Weight = 1.97992064,	Cost function = 0.03651755
# DIFF:		Bias = 1.212e-05,	Weight = -3.954e-05,	Cost function = -0.0
#
# Epoch 236:	Bias = 19.95958879,	Weight = 1.97988243,	Cost function = 0.03651755
# DIFF:		Bias = 1.172e-05,	Weight = -3.821e-05,	Cost function = -0.0
#
# Epoch 237:	Bias = 19.95960011,	Weight = 1.9798455,	Cost function = 0.03651755
# DIFF:		Bias = 1.132e-05,	Weight = -3.693e-05,	Cost function = -0.0
#
# Epoch 238:	Bias = 19.95961105,	Weight = 1.97980982,	Cost function = 0.03651755
# DIFF:		Bias = 1.094e-05,	Weight = -3.568e-05,	Cost function = -0.0
#
# Epoch 239:	Bias = 19.95962162,	Weight = 1.97977534,	Cost function = 0.03651755
# DIFF:		Bias = 1.057e-05,	Weight = -3.448e-05,	Cost function = -0.0
#
# Epoch 240:	Bias = 19.95963184,	Weight = 1.97974201,	Cost function = 0.03651755
# DIFF:		Bias = 1.022e-05,	Weight = -3.332e-05,	Cost function = -0.0
#
# Epoch 241:	Bias = 19.95964171,	Weight = 1.97970981,	Cost function = 0.03651755
# DIFF:		Bias = 9.87e-06,	Weight = -3.22e-05,	Cost function = -0.0
#
# Epoch 242:	Bias = 19.95965125,	Weight = 1.97967869,	Cost function = 0.03651755
# DIFF:		Bias = 9.54e-06,	Weight = -3.112e-05,	Cost function = -0.0
#
# Epoch 243:	Bias = 19.95966047,	Weight = 1.97964862,	Cost function = 0.03651755
# DIFF:		Bias = 9.22e-06,	Weight = -3.007e-05,	Cost function = -0.0
#
# Epoch 244:	Bias = 19.95966938,	Weight = 1.97961956,	Cost function = 0.03651754
# DIFF:		Bias = 8.91e-06,	Weight = -2.906e-05,	Cost function = -0.0
#
# Epoch 245:	Bias = 19.95967799,	Weight = 1.97959148,	Cost function = 0.03651754
# DIFF:		Bias = 8.61e-06,	Weight = -2.808e-05,	Cost function = -0.0
#
# Epoch 246:	Bias = 19.95968631,	Weight = 1.97956434,	Cost function = 0.03651754
# DIFF:		Bias = 8.32e-06,	Weight = -2.714e-05,	Cost function = -0.0
#
# Epoch 247:	Bias = 19.95969435,	Weight = 1.97953812,	Cost function = 0.03651754
# DIFF:		Bias = 8.04e-06,	Weight = -2.622e-05,	Cost function = -0.0
#
# Epoch 248:	Bias = 19.95970212,	Weight = 1.97951278,	Cost function = 0.03651754
# DIFF:		Bias = 7.77e-06,	Weight = -2.534e-05,	Cost function = -0.0
#
# Epoch 249:	Bias = 19.95970963,	Weight = 1.97948829,	Cost function = 0.03651754
# DIFF:		Bias = 7.51e-06,	Weight = -2.449e-05,	Cost function = -0.0
#
# Epoch 250:	Bias = 19.95971688,	Weight = 1.97946462,	Cost function = 0.03651754
# DIFF:		Bias = 7.26e-06,	Weight = -2.367e-05,	Cost function = -0.0
#
# Epoch 251:	Bias = 19.95972389,	Weight = 1.97944175,	Cost function = 0.03651754
# DIFF:		Bias = 7.01e-06,	Weight = -2.287e-05,	Cost function = -0.0
#
# Epoch 252:	Bias = 19.95973067,	Weight = 1.97941965,	Cost function = 0.03651754
# DIFF:		Bias = 6.78e-06,	Weight = -2.21e-05,	Cost function = -0.0
#
# Epoch 253:	Bias = 19.95973721,	Weight = 1.9793983,	Cost function = 0.03651754
# DIFF:		Bias = 6.55e-06,	Weight = -2.136e-05,	Cost function = -0.0
#
# Epoch 254:	Bias = 19.95974354,	Weight = 1.97937766,	Cost function = 0.03651754
# DIFF:		Bias = 6.33e-06,	Weight = -2.064e-05,	Cost function = -0.0
#
# Epoch 255:	Bias = 19.95974965,	Weight = 1.97935772,	Cost function = 0.03651754
# DIFF:		Bias = 6.11e-06,	Weight = -1.994e-05,	Cost function = -0.0
#
# Epoch 256:	Bias = 19.95975556,	Weight = 1.97933845,	Cost function = 0.03651754
# DIFF:		Bias = 5.91e-06,	Weight = -1.927e-05,	Cost function = -0.0
#
# Epoch 257:	Bias = 19.95976127,	Weight = 1.97931982,	Cost function = 0.03651754
# DIFF:		Bias = 5.71e-06,	Weight = -1.862e-05,	Cost function = -0.0
#
# Epoch 258:	Bias = 19.95976679,	Weight = 1.97930183,	Cost function = 0.03651754
# DIFF:		Bias = 5.52e-06,	Weight = -1.8e-05,	Cost function = -0.0
#
# Epoch 259:	Bias = 19.95977212,	Weight = 1.97928444,	Cost function = 0.03651754
# DIFF:		Bias = 5.33e-06,	Weight = -1.739e-05,	Cost function = -0.0
#
# Epoch 260:	Bias = 19.95977727,	Weight = 1.97926763,	Cost function = 0.03651754
# DIFF:		Bias = 5.15e-06,	Weight = -1.681e-05,	Cost function = -0.0
#
# Epoch 261:	Bias = 19.95978225,	Weight = 1.97925139,	Cost function = 0.03651754
# DIFF:		Bias = 4.98e-06,	Weight = -1.624e-05,	Cost function = -0.0
#
# Epoch 262:	Bias = 19.95978706,	Weight = 1.97923569,	Cost function = 0.03651754
# DIFF:		Bias = 4.81e-06,	Weight = -1.569e-05,	Cost function = -0.0
#
# Epoch 263:	Bias = 19.95979171,	Weight = 1.97922053,	Cost function = 0.03651754
# DIFF:		Bias = 4.65e-06,	Weight = -1.517e-05,	Cost function = -0.0
#
# Epoch 264:	Bias = 19.95979621,	Weight = 1.97920587,	Cost function = 0.03651754
# DIFF:		Bias = 4.49e-06,	Weight = -1.466e-05,	Cost function = -0.0
#
# Epoch 265:	Bias = 19.95980055,	Weight = 1.97919171,	Cost function = 0.03651754
# DIFF:		Bias = 4.34e-06,	Weight = -1.416e-05,	Cost function = -0.0
#
# Epoch 266:	Bias = 19.95980474,	Weight = 1.97917802,	Cost function = 0.03651754
# DIFF:		Bias = 4.2e-06,	Weight = -1.369e-05,	Cost function = -0.0
#
# Epoch 267:	Bias = 19.9598088,	Weight = 1.9791648,	Cost function = 0.03651754
# DIFF:		Bias = 4.05e-06,	Weight = -1.323e-05,	Cost function = -0.0
#
# Epoch 268:	Bias = 19.95981272,	Weight = 1.97915202,	Cost function = 0.03651754
# DIFF:		Bias = 3.92e-06,	Weight = -1.278e-05,	Cost function = -0.0
#
# Epoch 269:	Bias = 19.9598165,	Weight = 1.97913967,	Cost function = 0.03651754
# DIFF:		Bias = 3.79e-06,	Weight = -1.235e-05,	Cost function = -0.0
#
# Epoch 270:	Bias = 19.95982016,	Weight = 1.97912773,	Cost function = 0.03651754
# DIFF:		Bias = 3.66e-06,	Weight = -1.194e-05,	Cost function = -0.0
#
# Epoch 271:	Bias = 19.9598237,	Weight = 1.9791162,	Cost function = 0.03651754
# DIFF:		Bias = 3.54e-06,	Weight = -1.153e-05,	Cost function = -0.0
#
# Epoch 272:	Bias = 19.95982712,	Weight = 1.97910505,	Cost function = 0.03651754
# DIFF:		Bias = 3.42e-06,	Weight = -1.115e-05,	Cost function = -0.0
#
# Epoch 273:	Bias = 19.95983042,	Weight = 1.97909428,	Cost function = 0.03651754
# DIFF:		Bias = 3.3e-06,	Weight = -1.077e-05,	Cost function = -0.0
#
# Epoch 274:	Bias = 19.95983361,	Weight = 1.97908388,	Cost function = 0.03651754
# DIFF:		Bias = 3.19e-06,	Weight = -1.041e-05,	Cost function = -0.0
#
# Epoch 275:	Bias = 19.95983669,	Weight = 1.97907382,	Cost function = 0.03651754
# DIFF:		Bias = 3.08e-06,	Weight = -1.006e-05,	Cost function = -0.0
#
# Epoch 276:	Bias = 19.95983967,	Weight = 1.9790641,	Cost function = 0.03651754
# DIFF:		Bias = 2.98e-06,	Weight = -9.72e-06,	Cost function = -0.0
#
#
#
# 	TRAINING RESULTS
# Bias = 19.959839671318115
# Weight = 1.9790640981821177
# Cost function (train data) = 	0.03651753510385757
# Cost function (test data) = 	0.03778721595587194
